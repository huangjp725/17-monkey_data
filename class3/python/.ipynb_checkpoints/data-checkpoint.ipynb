# %% [markdown]
# # 利用 Pandas 进行简单数据分析

# %% [markdown]
# ## 1. 读取 excel

# %%
# coding=utf-8

import pandas as pd

# %%
file_name = "../源代码和数据/朝阳医院2016年销售数据.xlsx"

xls_file = pd.ExcelFile(file_name, dtype='object') # 统一先按照str读入，之后转换

table = xls_file.parse('Sheet1', dtype='object')

# %%
print type(xls_file)
print type(table)
# Out:
# <class 'pandas.io.excel.ExcelFile'>
# <class 'pandas.core.frame.DataFrame'>

# %%
table.head()
# Out:
#              购药时间           社保卡号    商品编码   商品名称 销售数量 应收金额   实收金额
# 0             NaN            NaN     NaN    NaN  NaN  NaN    NaN
# 1             NaN      001616527     NaN  三九感冒灵  NaN  NaN    NaN
# 2  2016-01-01 星期五      001616528  236701  三九感冒灵    7  196    182
# 3  2016-01-02 星期六      001616528  236701  三九感冒灵    3   84     84
# 4  2016-01-06 星期三  0010070343428  236701  三九感冒灵    3   84  73.92

# %% [markdown]
# ## 2. 数据预处理

# %% [markdown]
# ### 2.1 查看基本信息

# %%
print table.shape
print table.index
print table.columns
# Out:
# (6579, 7)
# RangeIndex(start=0, stop=6579, step=1)
# Index([u'购药时间', u'社保卡号', u'商品编码', u'商品名称', u'销售数量', u'应收金额', u'实收金额'], dtype='object')

# %%
print table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6579 entries, 0 to 6578
# Data columns (total 7 columns):
# 购药时间    6577 non-null object
# 社保卡号    6578 non-null object
# 商品编码    6577 non-null object
# 商品名称    6578 non-null object
# 销售数量    6577 non-null object
# 应收金额    6577 non-null object
# 实收金额    6577 non-null object
# dtypes: object(7)
# memory usage: 359.9+ KB
# None

# %%
print table.count()
# Out:
# 购药时间    6577
# 社保卡号    6578
# 商品编码    6577
# 商品名称    6578
# 销售数量    6577
# 应收金额    6577
# 实收金额    6577
# dtype: int64

# %% [markdown]
# ### 2.2 列重命名

# %% [markdown]
# pandas 的 rename 方法  <https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html>

# %%
col = {u'购药时间':'time',\
       u'社保卡号':'cardno',\
       u'商品编码':'drugId',\
       u'商品名称':'drugName',\
       u'销售数量':'saleNumber',\
       u'应收金额':'virtualmoney',\
       u'实收金额':'actualmoney'}

# %%
table.rename(columns = col, inplace = True)

# %%
table.head()
# Out:
#              time         cardno  drugId drugName saleNumber virtualmoney  \
# 0             NaN            NaN     NaN      NaN        NaN          NaN
# 1             NaN      001616527     NaN    三九感冒灵        NaN          NaN
# 2  2016-01-01 星期五      001616528  236701    三九感冒灵          7          196
# 3  2016-01-02 星期六      001616528  236701    三九感冒灵          3           84
# 4  2016-01-06 星期三  0010070343428  236701    三九感冒灵          3           84
#
#   actualmoney
# 0         NaN
# 1         NaN
# 2         182
# 3          84
# 4       73.92

# %% [markdown]
# ### 2.3 删除缺失值

# %% [markdown]
# pandas 的 dropna 方法  <https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html?highlight=dropna#pandas.DataFrame.dropna|>

# %%
dropna1 = table.dropna()
dropna2 = table.dropna(how = 'all')

# %%
dropna1.head()
# Out:
#              time         cardno  drugId drugName saleNumber virtualmoney  \
# 2  2016-01-01 星期五      001616528  236701    三九感冒灵          7          196
# 3  2016-01-02 星期六      001616528  236701    三九感冒灵          3           84
# 4  2016-01-06 星期三  0010070343428  236701    三九感冒灵          3           84
# 5  2016-01-11 星期一     0013389528  236701    三九感冒灵          1           28
# 6  2016-01-15 星期五    00101554328  236701    三九感冒灵          8          224
#
#   actualmoney
# 2         182
# 3          84
# 4       73.92
# 5          28
# 6         208

# %%
dropna2.head()
# Out:
#              time         cardno  drugId drugName saleNumber virtualmoney  \
# 1             NaN      001616527     NaN    三九感冒灵        NaN          NaN
# 2  2016-01-01 星期五      001616528  236701    三九感冒灵          7          196
# 3  2016-01-02 星期六      001616528  236701    三九感冒灵          3           84
# 4  2016-01-06 星期三  0010070343428  236701    三九感冒灵          3           84
# 5  2016-01-11 星期一     0013389528  236701    三九感冒灵          1           28
#
#   actualmoney
# 1         NaN
# 2         182
# 3          84
# 4       73.92
# 5          28

# %% [markdown]
# ### 2.4 处理日期

# %%
def split_datetime_weekday(t_w_column):
    
    datetime_list = [x.split()[0] for x in t_w_column ]
    weekday_list = [x.split()[1] for x in t_w_column]
    
    return datetime_list, weekday_list

# %%
datetime_list, weekday_list = split_datetime_weekday(dropna1.loc[:,'time'])
dropna1.loc[:,'datetime'] = pd.to_datetime(datetime_list)
dropna1.loc[:, 'weekday'] = weekday_list

# %%
dropna1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6577 entries, 2 to 6578
# Data columns (total 9 columns):
# time            6577 non-null object
# cardno          6577 non-null object
# drugId          6577 non-null object
# drugName        6577 non-null object
# saleNumber      6577 non-null object
# virtualmoney    6577 non-null object
# actualmoney     6577 non-null object
# datetime        6577 non-null datetime64[ns]
# weekday         6577 non-null object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 513.8+ KB

# %% [markdown]
# ### 2.5 数据类型转换

# %% [markdown]
# * saleNumber    virtualmoney    actualmoney  三个 columns 的数据类型转换

# %% [markdown]
# * astype 方法 <https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html?highlight=astype#pandas.DataFrame.astype>

# %%
dropna1['saleNumber'] = dropna1['saleNumber'].astype('float64')
dropna1['virtualmoney'] = dropna1['virtualmoney'].astype('float64')
dropna1['actualmoney'] = dropna1['actualmoney'].astype('float64')
# Out:
# /Users/yuyang/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/yuyang/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/yuyang/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# * <http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy>

# %% [markdown]
# * 对比两种索引形式 1. df[index][column]  2. df.loc[index:column] 为什么 后者更好
#
# 1. 是先索引第一层级[index]，返回了 Dataframe 的对象，然后对这个对象再次索引 [column],所以可以看做是一种连续两次的线性操作
# 2. iloc 索引则是利用了一个组合的索引，pandas 可以把这个返回对象当做一个整体处理，同时速度上也比第一种快。

# %%
dropna1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6580 entries, 2 to actualmoney
# Data columns (total 9 columns):
# time            6577 non-null object
# cardno          6577 non-null object
# drugId          6577 non-null object
# drugName        6577 non-null object
# saleNumber      6577 non-null float64
# virtualmoney    6577 non-null float64
# actualmoney     6577 non-null float64
# datetime        6577 non-null datetime64[ns]
# weekday         6577 non-null object
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 834.1+ KB

# %% [markdown]
# ## 2.6 排序

# %% [markdown]
# * 按销售时间对数据进行降序排列

# %% [markdown]
# * 老的 sort 方法好像已经改名成为 sort_values 了，找了半天。<https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html?highlight=sort_values#pandas.DataFrame.sort_values>

# %%
dropna1.sort_values("time")
# Out:
#                         time         cardno   drugId             drugName  \
# 2             2016-01-01 星期五      001616528   236701                三九感冒灵
# 401           2016-01-01 星期五  0010074599128  2367011                  开博通
# 400           2016-01-01 星期五  0010072612028  2367011                  开博通
# 3890          2016-01-01 星期五  0010014289328   866851          缬沙坦分散片(易达乐)
# 2700          2016-01-01 星期五     0013448228   861507        苯磺酸氨氯地平片(安内真)
# 3861          2016-01-01 星期五  0010073966328   866634          硝苯地平控释片(欣然)
# 2459          2016-01-01 星期五     0011811728   861492        x硝苯地平缓释片(伲福达)
# 6232          2016-01-01 星期五  0010015658428   861405        苯磺酸氨氯地平片(络活喜)
# 1192          2016-01-01 星期五  0010073966328   861409         非洛地平缓释片(波依定)
# 5041          2016-01-01 星期五  0010017493928   868042       马来酸左旋氨氯地平片(玄宁)
# 5051          2016-01-01 星期五    00107891628   868107       厄贝沙坦氢氯噻嗪片(安博诺)
# 1479          2016-01-01 星期五      001616528   861456       酒石酸美托洛尔片(倍他乐克)
# 5776          2016-01-01 星期五     0013169628   861462                珍菊降压片
# 1905          2016-01-01 星期五  0010060654328   861458   复方利血平氨苯蝶啶片(北京降压0号)
# 266           2016-01-01 星期五    00101470528   236709                  心痛定
# 2180          2016-01-01 星期五     0012697828   861464        复方利血平片(复方降压片)
# 2179          2016-01-01 星期五    00103283128   861464        复方利血平片(复方降压片)
# 4564          2016-01-01 星期五  0010074599128   874684       厄贝沙坦氢氯噻嗪片(依伦平)
# 895           2016-01-01 星期五     0011743428   861405        苯磺酸氨氯地平片(络活喜)
# 896           2016-01-01 星期五     0013331728   861405        苯磺酸氨氯地平片(络活喜)
# 897           2016-01-01 星期五     0013401428   861405        苯磺酸氨氯地平片(络活喜)
# 6484          2016-01-01 星期五     0011778628  2367011                  开博通
# 6483          2016-01-01 星期五    00105526028  2367011                  开博通
# 3438          2016-01-01 星期五     0010616728   865099           硝苯地平片(心痛定)
# 1478          2016-01-01 星期五     0011811728   861456       酒石酸美托洛尔片(倍他乐克)
# 4370          2016-01-01 星期五    00103283128   870921                卡托普利片
# 1308          2016-01-01 星期五      001616528   861417           雷米普利片(瑞素坦)
# 1477          2016-01-01 星期五    00107891628   861456       酒石酸美托洛尔片(倍他乐克)
# 4119          2016-01-02 星期六    00108946728   868107       厄贝沙坦氢氯噻嗪片(安博诺)
# 169           2016-01-02 星期六  0010039299528   861397      氨加黄敏胶囊(请报77504)
# ...                      ...            ...      ...                  ...
# 2124          2016-07-19 星期二  0010081634128   861459           吲达帕胺片(寿比山)
# 1905                 1.0          10.3          9.2 2016-01-01     星期五
# 266                  4.0         179.2        159.2 2016-01-01     星期五
# 2180                 4.0          10.0          9.4 2016-01-01     星期五
# 2179                 1.0           2.5          2.2 2016-01-01     星期五
# 4564                 5.0         118.0        118.0 2016-01-01     星期五
# 895                  1.0          34.5         31.0 2016-01-01     星期五
# 896                  2.0          69.0         62.0 2016-01-01     星期五
# 897                  1.0          34.5         31.0 2016-01-01     星期五
# 6484                 1.0          28.0         25.0 2016-01-01     星期五
# 6483                 3.0          84.0         75.0 2016-01-01     星期五
# 3438                 2.0           3.4          3.0 2016-01-01     星期五
# 1478                 1.0           7.0          6.3 2016-01-01     星期五
# 4370                 1.0           2.4          2.2 2016-01-01     星期五
# 1308                 1.0          28.5         28.5 2016-01-01     星期五
# 1477                 2.0          14.0         12.6 2016-01-01     星期五
# 4119                 1.0          38.8         35.0 2016-01-02     星期六
# 169                  2.0          35.0         31.0 2016-01-02     星期六
# ...                  ...           ...          ...        ...     ...
# 2124                 2.0          33.0         29.6 2016-07-19     星期二
# 2405                 1.0           3.7          3.3 2016-07-19     星期二
# 4465                 2.0          34.0         30.0 2016-07-19     星期二
# 4466                 2.0          34.0         30.0 2016-07-19     星期二
# 5884                 1.0          16.8         16.8 2016-07-19     星期二
# 3801                 6.0          69.0         57.5 2016-07-19     星期二
# 4464                 2.0          34.0         30.0 2016-07-19     星期二
# 5340                 2.0           2.4          2.0 2016-07-19     星期二
# 3282                 2.0          65.0         57.6 2016-07-19     星期二
# 3197                 1.0          38.0         33.5 2016-07-19     星期二
# 867                  2.0          62.0         56.0 2016-07-19     星期二
# 866                  2.0          62.0         56.0 2016-07-19     星期二
# 865                  2.0          62.0         56.0 2016-07-19     星期二
# 864                  4.0         124.0        118.0 2016-07-19     星期二
# 863                  1.0          31.0         28.0 2016-07-19     星期二
# 3746                 2.0           2.4          2.0 2016-07-19     星期二
# 3747                 2.0           2.4          2.0 2016-07-19     星期二
# 1434                 2.0          71.6         64.0 2016-07-19     星期二
# 4082                 2.0          35.8         31.6 2016-07-19     星期二
# 4081                 2.0          35.8         31.6 2016-07-19     星期二
# 4286                 4.0          88.0         88.0 2016-07-19     星期二
# 4285                 1.0          22.0         19.5 2016-07-19     星期二
# 5341                 1.0           1.2          1.0 2016-07-19     星期二
# 58                   1.0          28.0         28.0 2016-07-19     星期二
# 3283                 2.0          65.0         57.6 2016-07-19     星期二
# 2406                 1.0           3.7          3.3 2016-07-19     星期二
# 4253                 1.0          16.5         16.5 2016-07-19     星期二
# saleNumber           NaN           NaN          NaN        NaT     NaN
# virtualmoney         NaN           NaN          NaN        NaT     NaN
# actualmoney          NaN           NaN          NaN        NaT     NaN
#
# [6580 rows x 9 columns]

# %% [markdown]
# ## 3 简单数据分析

# %% [markdown]
# * 月均消费次数
# * 月均消费金额
# * 客单价
# * 消费趋势
